# %% [markdown]
# ## Installs.

# %%
# installs.
# !pip install category_encoders
# Out:
# Collecting category_encoders
#   Downloading https://files.pythonhosted.org/packages/44/57/fcef41c248701ee62e8325026b90c432adea35555cbc870aff9cfba23727/category_encoders-2.2.2-py2.py3-none-any.whl (80kB)
#      |████████████████████████████████| 81kB 1.7MB/s
# Requirement already satisfied: scipy>=1.0.0 in /usr/local/lib/python3.6/dist-packages (from category_encoders) (1.4.1)
# Requirement already satisfied: statsmodels>=0.9.0 in /usr/local/lib/python3.6/dist-packages (from category_encoders) (0.10.2)
# Requirement already satisfied: patsy>=0.5.1 in /usr/local/lib/python3.6/dist-packages (from category_encoders) (0.5.1)
# Requirement already satisfied: pandas>=0.21.1 in /usr/local/lib/python3.6/dist-packages (from category_encoders) (1.0.3)
# Requirement already satisfied: scikit-learn>=0.20.0 in /usr/local/lib/python3.6/dist-packages (from category_encoders) (0.22.2.post1)
# Requirement already satisfied: numpy>=1.14.0 in /usr/local/lib/python3.6/dist-packages (from category_encoders) (1.18.4)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from patsy>=0.5.1->category_encoders) (1.12.0)
# Requirement already satisfied: python-dateutil>=2.6.1 in /usr/local/lib/python3.6/dist-packages (from pandas>=0.21.1->category_encoders) (2.8.1)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.6/dist-packages (from pandas>=0.21.1->category_encoders) (2018.9)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.6/dist-packages (from scikit-learn>=0.20.0->category_encoders) (0.15.1)
# Installing collected packages: category-encoders
# Successfully installed category-encoders-2.2.2

# %% [markdown]
# ## Imports.

# %%
# imports.
import pandas as pd
import numpy as np
import requests
import category_encoders as ce
from sklearn.model_selection import train_test_split
from sklearn.impute import SimpleImputer
from sklearn.ensemble import RandomForestRegressor
from sklearn.pipeline import make_pipeline
pd.set_option('display.float_format', lambda x: '%.2f' % x)

# %%
# read in the cleaned original data.
df_tr = pd.read_csv('https://raw.githubusercontent.com/CVanchieri/DataSets/master/WorldBankDeforestation/WorldBank_1990_2018.csv')

# %% [markdown]
# ## Train Data.

# %%
# Set train data.
train = df_tr.copy()
train = train.drop(columns=['Unnamed: 0'])
train.head()
# Out:
#   Country Code  ...  Forest area (% of land area)
# 0          ABW  ...                          2.33
# 1          AFG  ...                          2.07
# 2          AGO  ...                         48.91
# 3          ALB  ...                         28.79
# 4          AND  ...                         34.04
#
# [5 rows x 11 columns]

# %% [markdown]
# ### Train/Val Split.

# %%
# Set variables.
features = train.columns[:-1].tolist()
target = 'Forest area (% of land area)'

X = train.drop(columns=target)
y = train[target]

# %%
# Use train/val split on the data.
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=1)
X_train.shape, y_train.shape, X_val.shape, y_val.shape, X_test.shape, y_test.shape
# Out:
# ((4899, 10), (4899,), (1225, 10), (1225,), (1532, 10), (1532,))

# %% [markdown]
# ### Random Forest Pipeline.

# %%
# random forest pipeline.
pipeline = make_pipeline(
    ce.OneHotEncoder(), 
    RandomForestRegressor(n_estimators=100, random_state=42, n_jobs=-1)
)
pipeline.fit(X_train, y_train)

print ('Training Accuracy', pipeline.score(X_train, y_train))
print('Validation Accuracy', pipeline.score(X_val, y_val))
y_pred = pipeline.predict(X_val)
# Out:
# Training Accuracy 0.9986954216649627
# Validation Accuracy 0.9929648523153405

# %% [markdown]
# ## Test Data.

# %%
# read in the cleaned predictions data frame.
df_te = pd.read_csv('https://raw.githubusercontent.com/CVanchieri/DataSets/master/WorldBankDeforestation/WorldBank_2019_2120.csv')

# %%
# Set the test data.
test = df_te.copy()
test = test.drop(columns=['Unnamed: 0'])
test.head()
# Out:
#   Country Code  ...  Forest area (% of land area)
# 0          ABW  ...                          2.33
# 1          AFG  ...                          2.07
# 2          AGO  ...                         46.05
# 3          ALB  ...                         28.14
# 4          AND  ...                         34.04
#
# [5 rows x 11 columns]

# %% [markdown]
# ### Random Forest Pipeline.

# %%
# set the variables.
features = test.columns[:-1].tolist()
target = 'Forest area (% of land area)'

X_test = test[features]
y_test = test[target]

pipeline.fit(X_test, y_test)
y_pred = pipeline.predict(X_test)

print ('Test Accuracy', pipeline.score(X_test, y_test))
y_pred
# Out:
# Test Accuracy 0.9998526451418099
# array([  2.4116666 ,   2.2803321 ,  44.96266689, ...,   7.47180292,
#         42.56087829, -49.36206047])

# %%
# Set the predictions on the data frame.
test['Forest area (% of land area)'] = pd.Series(y_pred)
# Merge the train and test data for one dataframe.
predictions = pd.concat([train, test])

# %%
# show the data frame shape.
print(predictions.shape)
# show the data frame with headers.
predictions.head()
# Out:
# (34584, 11)
#   Country Code  ...  Forest area (% of land area)
# 0          ABW  ...                          2.33
# 1          AFG  ...                          2.07
# 2          AGO  ...                         48.91
# 3          ALB  ...                         28.79
# 4          AND  ...                         34.04
#
# [5 rows x 11 columns]

# %%
# Function to add in some country names.
def label_race (row):
   if row['Country Code'] == 'USA' :
      return 'United States of America'
   if row['Country Code'] == 'CHA' :
      return 'China'
   if row['Country Code'] == 'CAN' :
      return 'Canada'
   if row['Country Code'] == 'AUS' :
      return 'Australia'
   if row['Country Code'] == 'ARG' :
      return 'Argentina'
   if row['Country Code'] == 'BRA':
      return 'Brazil'
   if row['Country Code'] == 'BEL':
      return 'Belgium'   
   if row['Country Code'] == 'CHL':
      return 'Chile'
   if row['Country Code'] == 'DEU' :
      return 'Germany'
   if row['Country Code'] == 'ZAF' :
      return 'South Africa'
   if row['Country Code']  == 'NZL':
      return 'New Zealnd'
   if row['Country Code'] == 'GBR':
      return 'United Kingdom'
   if row['Country Code'] == 'IND' :
      return 'India'
   if row['Country Code'] == 'KHM' :
      return 'Cambodia'
   if row['Country Code']  == 'THA':
      return 'Thailand'
   if row['Country Code'] == 'VNM':
      return 'Vietnam'
   if row['Country Code'] == 'HIC' :
      return 'High Income Countries'
   if row['Country Code']  == 'MIC':
      return 'Middle Income Countries'
   if row['Country Code'] == 'LIC':
      return 'Low Income Countries'
   return 'Other'

# %%
# make a copy of the dataframe.
final_c = predictions.copy()

# %%
# Apply the function to the datarame.
final_c.apply (lambda row: label_race(row), axis=1)
final_c['Country Name'] = final_c.apply (lambda row: label_race(row), axis=1)
final_c = final_c[['Country Name',
                                  'Country Code',
                                  'Year',
                                  'Agricultural land (sq. km)',
                                  'Electric power consumption (kWh per capita)',
                                  'GDP per capita growth (annual %)',
                                  'Livestock production index (2004-2006 = 100)',
                                  'Ores and metals exports (% of merchandise exports)',
                                  'Urban population',
                                  'Crop production index (2004-2006 = 100)',
                                  'Food production index (2004-2006 = 100)',
                                  'Forest area (% of land area)']]

# %%
# Clean the dataframe.
final_c = final_c[final_c['Country Name'] != 'Other']
final_c = final_c[['Country Name',
 'Country Code',
 'Year',
 'Agricultural land (sq. km)',
 'Electric power consumption (kWh per capita)',
 'GDP per capita growth (annual %)',
 'Livestock production index (2004-2006 = 100)',
 'Ores and metals exports (% of merchandise exports)',
 'Urban population',
 'Crop production index (2004-2006 = 100)',
 'Food production index (2004-2006 = 100)',
 'Forest area (% of land area)']]

# %%
print(final_c.shape)
final_c.tail()
# Out:
# (2358, 12)
#                    Country Name  ... Forest area (% of land area)
# 26842                New Zealnd  ...                        44.84
# 26895                  Thailand  ...                        44.16
# 26913  United States of America  ...                        38.27
# 26919                   Vietnam  ...                       127.97
# 26925              South Africa  ...                         7.47
#
# [5 rows x 12 columns]

# %%
# Download predictions result as a csv.
from google.colab import files 
final_c.to_csv('Deforestation_Predictions.csv', index=False)
files.download('Deforestation_Predictions.csv')

# %%
# Download predictions result as a json.
final_c.to_json('Deforestation_Predictions.json', orient= 'records')
files.download('Deforestation_Predictions.json')

# %% [markdown]
# ## Connecting Data.

# %%
# JSON file.
df = pd.read_json("https://raw.githubusercontent.com/Lambda-School-Labs/earth-dashboard-ds/feature/DeforestationRC2VisualizationNotebooks/Notebooks/Deforestation_Predictions.json")
print(df.shape)
df.head()
# Out:
# (2358, 12)
#   Country Name  ... Forest area (% of land area)
# 0    Argentina  ...                        12.71
# 1    Australia  ...                        16.73
# 2      Belgium  ...                        31.08
# 3       Brazil  ...                        65.41
# 4       Canada  ...                        38.30
#
# [5 rows x 12 columns]

# %%
# CSV file.
df = pd.read_csv("https://raw.githubusercontent.com/Lambda-School-Labs/earth-dashboard-ds/feature/DeforestationRC2VisualizationNotebooks/Notebooks/Deforestation_Predictions.csv")
print(df.shape)
df.head()
# Out:
# (2358, 12)
#   Country Name  ... Forest area (% of land area)
# 0    Argentina  ...                        12.71
# 1    Australia  ...                        16.73
# 2      Belgium  ...                        31.08
# 3       Brazil  ...                        65.41
# 4       Canada  ...                        38.30
#
# [5 rows x 12 columns]

# %%
# JSON file.
url = "https://raw.githubusercontent.com/Lambda-School-Labs/earth-dashboard-ds/feature/DeforestationRC2VisualizationNotebooks/Notebooks/Deforestation_Predictions.json"
response = requests.get(url)
# show the status code.
print(response.status_code)
df = response.json()

df
# Out:
# 200
# [{'Agricultural land (sq. km)': 1275650.0,
#   'Country Code': 'ARG',
#   'Country Name': 'Argentina',
#   'Crop production index (2004-2006 = 100)': 53.11,
#   'Electric power consumption (kWh per capita)': 1303.9778990247,
#   'Food production index (2004-2006 = 100)': 63.01,
#   'Forest area (% of land area)': 12.7135335022,
#   'GDP per capita growth (annual %)': -3.8741031654,
#   'Livestock production index (2004-2006 = 100)': 84.39,
#   'Ores and metals exports (% of merchandise exports)': 2.4468496926,
#   'Urban population': 28373007.0,
#   'Year': 1990},
#  {'Agricultural land (sq. km)': 4644810.0,
#   'Country Code': 'AUS',
#   'Country Name': 'Australia',
#   'Crop production index (2004-2006 = 100)': 59.46,
#   'Electric power consumption (kWh per capita)': 8527.2280853906,
#   'Food production index (2004-2006 = 100)': 69.98,
#   'Forest area (% of land area)': 16.7320984601,
#   'GDP per capita growth (annual %)': 2.0490820195,
#   'Livestock production index (2004-2006 = 100)': 86.42,
#   'Ores and metals exports (% of merchandise exports)': 20.8102828456,
#   'Urban population': 14579227.0,
#   'Year': 1990},
#  {'Agricultural land (sq. km)': 78460.0,
#   'Country Code': 'BEL',
#   'Country Name': 'Belgium',
#   'Crop production index (2004-2006 = 100)': 71.6924417936,
#   'Electric power consumption (kWh per capita)': 6380.3132197542,
#   'Food production index (2004-2006 = 100)': 69.365,
#   'Forest area (% of land area)': 31.0779996607,
#   'GDP per capita growth (annual %)': 2.8302681209,
#   'Livestock production index (2004-2006 = 100)': 67.4938481231,
#   'Ores and metals exports (% of merchandise exports)': 4.2221429357,
#   'Urban population': 9606261.0,
#   'Year': 1990},
#  {'Agricultural land (sq. km)': 2416080.0,
#   'Country Code': 'BRA',
#   'Country Name': 'Brazil',
#   'Crop production index (2004-2006 = 100)': 59.02,
#   'Electric power consumption (kWh per capita)': 1460.7603487879,
#   'Food production index (2004-2006 = 100)': 51.4,
#   'Forest area (% of land area)': 65.4098878459,
#   'GDP per capita growth (annual %)': -4.8418710002,
#   'Livestock production index (2004-2006 = 100)': 44.88,
#   'Ores and metals exports (% of merchandise exports)': 13.5586350332,
#   'Urban population': 110146163.0,
#   'Year': 1990},
#  {'Agricultural land (sq. km)': 677680.0,
#   'Country Code': 'CAN',
#   'Country Name': 'Canada',
#   'Crop production index (2004-2006 = 100)': 82.97,
#   'Electric power consumption (kWh per capita)': 16167.3745586043,
#   'Food production index (2004-2006 = 100)': 74.11,
#   'Forest area (% of land area)': 38.2990726353,
#   'GDP per capita growth (annual %)': -1.3341439167,
#   'Livestock production index (2004-2006 = 100)': 68.1,
#   'Ores and metals exports (% of merchandise exports)': 8.5697469366,
#   'Urban population': 21206427.0,
#   'Year': 1990},
#  {'Agricultural land (sq. km)': 158990.0,
#   'Country Code': 'CHL',
#   'Country Name': 'Chile',
#   'Crop production index (2004-2006 = 100)': 60.09,
#   'Electric power consumption (kWh per capita)': 1237.624601467,
#   'Food production index (2004-2006 = 100)': 57.57,
#   'Forest area (% of land area)': 20.5276966674,
#   'GDP per capita growth (annual %)': 1.6532088923,
#   'Livestock production index (2004-2006 = 100)': 55.08,
#   'Ores and metals exports (% of merchandise exports)': 54.6149294461,
#   'Urban population': 11053911.0,
#   'Year': 1990},
#  {'Agricultural land (sq. km)': 180320.0,
#   'Country Code': 'DEU',
#   'Country Name': 'Germany',
#   'Crop production index (2004-2006 = 100)': 94.07,
#   'Electric power consumption (kWh per capita)': 6639.7316914605,
#   'Food production index (2004-2006 = 100)': 108.34,
#   'Forest area (% of land area)': 32.3661673302,
#   'GDP per capita growth (annual %)': 4.35163906,
#   'Livestock production index (2004-2006 = 100)': 114.6,
#   'Ores and metals exports (% of merchandise exports)': 2.518108834,
#   'Urban population': 58079842.0,
#   'Year': 1990},
#  {'Agricultural land (sq. km)': 182030.0,
#   'Country Code': 'GBR',
#   'Country Name': 'United Kingdom',
#   'Crop production index (2004-2006 = 100)': 104.91,
#   'Electric power consumption (kWh per capita)': 5356.575210001,
#   'Food production index (2004-2006 = 100)': 107.2,
#   'Forest area (% of land area)': 11.4826602736,
#   'GDP per capita growth (annual %)': 0.4386279014,
#   'Livestock production index (2004-2006 = 100)': 107.37,
#   'Ores and metals exports (% of merchandise exports)': 3.1460626465,
#   'Urban population': 44733264.0,
#   'Year': 1990},
#  {'Agricultural land (sq. km)': 13204639.0064245,
#   'Country Code': 'HIC',
#   'Country Name': 'High Income Countries',
#   'Crop production index (2004-2006 = 100)': 87.3985312049,
#   'Electric power consumption (kWh per capita)': 7296.3104253087,
#   'Food production index (2004-2006 = 100)': 87.1639183684,
#   'Forest area (% of land area)': 28.4507844367,
#   'GDP per capita growth (annual %)': 2.3518382476,
#   'Livestock production index (2004-2006 = 100)': 88.4426138239,
#   'Ores and metals exports (% of merchandise exports)': 3.5889518737,
#   'Urban population': 745675963.0,
#   'Year': 1990},
#  {'Agricultural land (sq. km)': 1814130.0,
#   'Country Code': 'IND',
#   'Country Name': 'India',
#   'Crop production index (2004-2006 = 100)': 72.59,
#   'Electric power consumption (kWh per capita)': 272.0634837438,
#   'Food production index (2004-2006 = 100)': 70.13,
#   'Forest area (% of land area)': 21.505184667,
#   'GDP per capita growth (annual %)': 3.3650730428,
#   'Livestock production index (2004-2006 = 100)': 60.66,
#   'Ores and metals exports (% of merchandise exports)': 5.1592403665,
#   'Urban population': 223096279.0,
#   'Year': 1990},
#  {'Agricultural land (sq. km)': 44550.0,
#   'Country Code': 'KHM',
#   'Country Name': 'Cambodia',
#   'Crop production index (2004-2006 = 100)': 47.14,
#   'Electric power consumption (kWh per capita)': 1237.5215398653,
#   'Food production index (2004-2006 = 100)': 46.45,
#   'Forest area (% of land area)': 73.328801269,
#   'GDP per capita growth (annual %)': 1.3151118292,
#   'Livestock production index (2004-2006 = 100)': 48.39,
#   'Ores and metals exports (% of merchandise exports)': 2.7519731469,
#   'Urban population': 1395346.0,
#   'Year': 1990},
#  {'Agricultural land (sq. km)': 4446043.99902344,
#   'Country Code': 'LIC',
#   'Country Name': 'Low Income Countries',
#   'Crop production index (2004-2006 = 100)': 68.5056642767,
#   'Electric power consumption (kWh per capita)': 1237.5215398653,
#   'Food production index (2004-2006 = 100)': 67.8477278427,
#   'Forest area (% of land area)': 29.8374800516,
#   'GDP per capita growth (annual %)': -2.2312852286,
#   'Livestock production index (2004-2006 = 100)': 67.4476962462,
#   'Ores and metals exports (% of merchandise exports)': 2.7519731469,
#   'Urban population': 77327042.0,
#   'Year': 1990},
#  {'Agricultural land (sq. km)': 23019651.0004845,
#   'Country Code': 'MIC',
#   'Country Name': 'Middle Income Countries',
#   'Crop production index (2004-2006 = 100)': 61.5101219907,
#   'Electric power consumption (kWh per capita)': 903.26073535,
#   'Food production index (2004-2006 = 100)': 58.091899705,
#   'Forest area (% of land area)': 34.3290033904,
#   'GDP per capita growth (annual %)': 0.2367824706,
#   'Livestock production index (2004-2006 = 100)': 53.2979245014,
#   'Ores and metals exports (% of merchandise exports)': 4.3709666476,
#   'Urban population': 1448802631.0,
#   'Year': 1990},
#  {'Agricultural land (sq. km)': 161820.0,
#   'Country Code': 'NZL',
#   'Country Name': 'New Zealnd',
#   'Crop production index (2004-2006 = 100)': 75.47,
#   'Electric power consumption (kWh per capita)': 8972.3106492882,
#   'Food production index (2004-2006 = 100)': 65.05,
#   'Forest area (% of land area)': 36.6791994227,
#   'GDP per capita growth (annual %)': -0.7673634801,
#   'Livestock production index (2004-2006 = 100)': 67.54,
#   'Ores and metals exports (% of merchandise exports)': 5.6661315304,
#   'Urban population': 2821739.0,
#   'Year': 1990},
#  {'Agricultural land (sq. km)': 213830.0,
#   'Country Code': 'THA',
#   'Country Name': 'Thailand',
#   'Crop production index (2004-2006 = 100)': 62.07,
#   'Electric power consumption (kWh per capita)': 709.5524598331,
#   'Food production index (2004-2006 = 100)': 68.44,
#   'Forest area (% of land area)': 27.4129460354,
#   'GDP per capita growth (annual %)': 9.6222185571,
#   'Livestock production index (2004-2006 = 100)': 79.91,
#   'Ores and metals exports (% of merchandise exports)': 1.0391751264,
#   'Urban population': 16641681.0,
#   'Year': 1990},
#  {'Agricultural land (sq. km)': 4269480.0,
#   'Country Code': 'USA',
#   'Country Name': 'United States of America',
#   'Crop production index (2004-2006 = 100)': 79.41,
#   'Electric power consumption (kWh per capita)': 11713.3317042099,
#   'Food production index (2004-2006 = 100)': 77.94,
#   'Forest area (% of land area)': 33.0223082097,
#   'GDP per capita growth (annual %)': 0.7414815181,
#   'Livestock production index (2004-2006 = 100)': 78.8,
#   'Ores and metals exports (% of merchandise exports)': 3.0531623248,
#   'Urban population': 187966119.0,
#   'Year': 1990},
#  {'Agricultural land (sq. km)': 67260.0,
#   'Country Code': 'VNM',
#   'Country Name': 'Vietnam',
#   'Crop production index (2004-2006 = 100)': 45.72,
#   'Electric power consumption (kWh per capita)': 95.2508956541,
#   'Food production index (2004-2006 = 100)': 49.2,
#   'Forest area (% of land area)': 28.7658607023,
#   'GDP per capita growth (annual %)': 2.8770079408,
#   'Livestock production index (2004-2006 = 100)': 38.53,
#   'Ores and metals exports (% of merchandise exports)': 2.7519731469,
#   'Urban population': 13772504.0,
#   'Year': 1990},
#  {'Agricultural land (sq. km)': 956000.0,
#   'Country Code': 'ZAF',
#   'Country Name': 'South Africa',
#   'Crop production index (2004-2006 = 100)': 83.78,
#   'Electric power consumption (kWh per capita)': 4238.7457195225,
#   'Food production index (2004-2006 = 100)': 79.57,
#   'Forest area (% of land area)': 7.6177365241,
#   'GDP per capita growth (annual %)': -2.6756139492,
#   'Livestock production index (2004-2006 = 100)': 79.79,
#   'Ores and metals exports (% of merchandise exports)': 2.7519731469,
#   'Urban population': 19149881.0,
#   'Year': 1990},
#  {'Agricultural land (sq. km)': 1276600.0,
#   'Country Code': 'ARG',
#   'Country Name': 'Argentina',
#   'Crop production index (2004-2006 = 100)': 56.99,
#   'Electric power consumption (kWh per capita)': 1347.5921279362,
#   'Food production index (2004-2006 = 100)': 65.3,
#   'Forest area (% of land area)': 12.6063599526,
#   'GDP per capita growth (annual %)': 7.6143428188,
#   'Livestock production index (2004-2006 = 100)': 83.18,
#   'Ores and metals exports (% of merchandise exports)': 1.6995876324,
#   'Urban population': 28887229.0,
#   'Year': 1991},
#  {'Agricultural land (sq. km)': 4629740.0,
#   'Country Code': 'AUS',
#   'Country Name': 'Australia',
#   'Crop production index (2004-2006 = 100)': 56.17,
#   'Electric power consumption (kWh per capita)': 8522.1592224022,
#   'Food production index (2004-2006 = 100)': 69.26,
#   'Forest area (% of land area)': 16.7360035406,
#   'GDP per capita growth (annual %)': -1.6586900011,
#   'Livestock production index (2004-2006 = 100)': 88.16,
#   'Ores and metals exports (% of merchandise exports)': 20.0979472287,
#   'Urban population': 14761055.0,
#   'Year': 1991},
#  {'Agricultural land (sq. km)': 67550.0,
#   'Country Code': 'BEL',
#   'Country Name': 'Belgium',
#   'Crop production index (2004-2006 = 100)': 72.9,
#   'Electric power consumption (kWh per capita)': 6655.4143811086,
#   'Food production index (2004-2006 = 100)': 71.6753342043,
#   'Forest area (% of land area)': 31.6768366114,
#   'GDP per capita growth (annual %)': 1.4553717279,
#   'Livestock production index (2004-2006 = 100)': 71.885,
#   'Ores and metals exports (% of merchandise exports)': 3.6851006844,
#   'Urban population': 9650427.0,
#   'Year': 1991},
#  {'Agricultural land (sq. km)': 2449410.0,
#   'Country Code': 'BRA',
#   'Country Name': 'Brazil',
#   'Crop production index (2004-2006 = 100)': 60.09,
#   'Electric power consumption (kWh per capita)': 1486.2245703968,
#   'Food production index (2004-2006 = 100)': 53.73,
#   'Forest area (% of land area)': 65.1056185946,
#   'GDP per capita growth (annual %)': -0.2584622,
#   'Livestock production index (2004-2006 = 100)': 49.03,
#   'Ores and metals exports (% of merchandise exports)': 14.3487020517,
#   'Urban population': 113265899.0,
#   'Year': 1991},
#  {'Agricultural land (sq. km)': 677530.0,
#   'Country Code': 'CAN',
#   'Country Name': 'Canada',
#   'Crop production index (2004-2006 = 100)': 81.54,
#   'Electric power consumption (kWh per capita)': 16181.5887481801,
#   'Food production index (2004-2006 = 100)': 73.52,
#   'Forest area (% of land area)': 38.2938938045,
#   'GDP per capita growth (annual %)': -3.2953916876,
#   'Livestock production index (2004-2006 = 100)': 67.0,
#   'Ores and metals exports (% of merchandise exports)': 7.8205156309,
#   'Urban population': 21482271.0,
#   'Year': 1991},
#  {'Agricultural land (sq. km)': 157890.0,
#   'Country Code': 'CHL',
#   'Country Name': 'Chile',
#   'Crop production index (2004-2006 = 100)': 63.43,
#   'Electric power consumption (kWh per capita)': 1313.943016132,
#   'Food production index (2004-2006 = 100)': 59.86,
#   'Forest area (% of land area)': 20.6044917576,
#   'GDP per capita growth (annual %)': 6.0418899749,
#   'Livestock production index (2004-2006 = 100)': 55.67,
#   'Ores and metals exports (% of merchandise exports)': 49.225733156,
#   'Urban population': 11254775.0,
#   'Year': 1991},
#  {'Agricultural land (sq. km)': 171360.0,
#   'Country Code': 'DEU',
#   'Country Name': 'Germany',
#   'Crop production index (2004-2006 = 100)': 83.28,
#   'Electric power consumption (kWh per capita)': 6564.7971947273,
#   'Food production index (2004-2006 = 100)': 101.17,
#   'Forest area (% of land area)': 32.3816354671,
#   'GDP per capita growth (annual %)': 4.3452200412,
#   'Livestock production index (2004-2006 = 100)': 107.63,
#   'Ores and metals exports (% of merchandise exports)': 2.3888783951,
#   'Urban population': 58625381.0,
#   'Year': 1991},
#  {'Agricultural land (sq. km)': 181430.0,
#   'Country Code': 'GBR',
#   'Country Name': 'United Kingdom',
#   'Crop production index (2004-2006 = 100)': 105.74,
#   'Electric power consumption (kWh per capita)': 5451.6771706182,
#   'Food production index (2004-2006 = 100)': 109.58,
#   'Forest area (% of land area)': 11.5554089929,
#   'GDP per capita growth (annual %)': -1.3933097796,
#   'Livestock production index (2004-2006 = 100)': 108.88,
#   'Ores and metals exports (% of merchandise exports)': 2.9145894417,
#   'Urban population': 44855736.0,
#   'Year': 1991},
#  {'Agricultural land (sq. km)': 13156015.0036937,
#   'Country Code': 'HIC',
#   'Country Name': 'High Income Countries',
#   'Crop production index (2004-2006 = 100)': 85.3715640841,
#   'Electric power consumption (kWh per capita)': 7473.1497545326,
#   'Food production index (2004-2006 = 100)': 86.2652023159,
#   'Forest area (% of land area)': 28.47785963,
#   'GDP per capita growth (annual %)': 0.7445872144,
#   'Livestock production index (2004-2006 = 100)': 88.4747256555,
#   'Ores and metals exports (% of merchandise exports)': 4.8965620176,
#   'Urban population': 754703686.0,
#   'Year': 1991},
#  {'Agricultural land (sq. km)': 1815860.0,
#   'Country Code': 'IND',
#   'Country Name': 'India',
#   'Crop production index (2004-2006 = 100)': 73.68,
#   'Electric power consumption (kWh per capita)': 290.8995775727,
#   'Food production index (2004-2006 = 100)': 71.13,
#   'Forest area (% of land area)': 21.5539879935,
#   'GDP per capita growth (annual %)': -0.9835745813,
#   'Livestock production index (2004-2006 = 100)': 61.68,
#   'Ores and metals exports (% of merchandise exports)': 5.3231535285,
#   'Urban population': 229752408.0,
#   'Year': 1991},
#  {'Agricultural land (sq. km)': 45100.0,
#   'Country Code': 'KHM',
#   'Country Name': 'Cambodia',
#   'Crop production index (2004-2006 = 100)': 46.04,
#   'Electric power consumption (kWh per capita)': 1266.2570072458,
#   'Food production index (2004-2006 = 100)': 47.49,
#   'Forest area (% of land area)': 72.5368241293,
#   'GDP per capita growth (annual %)': 0.0795646088,
#   'Livestock production index (2004-2006 = 100)': 58.21,
#   'Ores and metals exports (% of merchandise exports)': 2.7669993926,
#   'Urban population': 1475791.0,
#   'Year': 1991},
#  {'Agricultural land (sq. km)': 4463290.0,
#   'Country Code': 'LIC',
#   'Country Name': 'Low Income Countries',
#   'Crop production index (2004-2006 = 100)': 73.3257909897,
#   'Electric power consumption (kWh per capita)': 1266.2570072458,
#   'Food production index (2004-2006 = 100)': 72.0906684086,
#   'Forest area (% of land area)': 29.6940847891,
#   'GDP per capita growth (annual %)': -2.8092938574,
#   'Livestock production index (2004-2006 = 100)': 70.5394474424,
#   'Ores and metals exports (% of merchandise exports)': 2.7669993926,
#   'Urban population': 80677638.0,
#   'Year': 1991},
#  {'Agricultural land (sq. km)': 23156526.000236604,
#   'Country Code': 'MIC',
#   'Country Name': 'Middle Income Countries',
#   'Crop production index (2004-2006 = 100)': 63.1372213473,
#   'Electric power consumption (kWh per capita)': 906.5272512547,
#   'Food production index (2004-2006 = 100)': 59.9296592859,
#   'Forest area (% of land area)': 34.2524613036,
#   'GDP per capita growth (annual %)': -0.6446331122,
#   'Livestock production index (2004-2006 = 100)': 56.1720470052,
#   'Ores and metals exports (% of merchandise exports)': 3.8384618855,
#   'Urban population': 1493922280.0,
#   'Year': 1991},
#  {'Agricultural land (sq. km)': 161190.0,
#   'Country Code': 'NZL',
#   'Country Name': 'New Zealnd',
#   'Crop production index (2004-2006 = 100)': 73.13,
#   'Electric power consumption (kWh per capita)': 8842.3793310635,
#   'Food production index (2004-2006 = 100)': 69.07,
#   'Forest area (% of land area)': 36.8618723534,
#   'GDP per capita growth (annual %)': -5.7686886231,
#   'Livestock production index (2004-2006 = 100)': 71.93,
#   'Ores and metals exports (% of merchandise exports)': 5.1277751397,
#   'Urban population': 2969087.0,
#   'Year': 1991},
#  {'Agricultural land (sq. km)': 215160.0,
#   'Country Code': 'THA',
#   'Country Name': 'Thailand',
#   'Crop production index (2004-2006 = 100)': 66.02,
#   'Electric power consumption (kWh per capita)': 792.0854011792,
#   'Food production index (2004-2006 = 100)': 75.38,
#   'Forest area (% of land area)': 28.001330246,
#   'GDP per capita growth (annual %)': 7.2792912045,
#   'Livestock production index (2004-2006 = 100)': 88.79,
#   'Ores and metals exports (% of merchandise exports)': 0.6858909939,
#   'Urban population': 16936803.0,
#   'Year': 1991},
#  {'Agricultural land (sq. km)': 4269480.0,
#   'Country Code': 'USA',
#   'Country Name': 'United States of America',
#   'Crop production index (2004-2006 = 100)': 77.28,
#   'Electric power consumption (kWh per capita)': 12134.1721315039,
#   'Food production index (2004-2006 = 100)': 77.15,
#   'Forest area (% of land area)': 33.0341647687,
#   'GDP per capita growth (annual %)': -1.4341945151,
#   'Livestock production index (2004-2006 = 100)': 80.34,
#   'Ores and metals exports (% of merchandise exports)': 2.7762280401,
#   'Urban population': 191509147.0,
#   'Year': 1991},
#  {'Agricultural land (sq. km)': 67510.0,
#   'Country Code': 'VNM',
#   'Country Name': 'Vietnam',
#   'Crop production index (2004-2006 = 100)': 47.21,
#   'Electric power consumption (kWh per capita)': 98.7802546753,
#   'Food production index (2004-2006 = 100)': 49.82,
#   'Forest area (% of land area)': 29.4921514966,
#   'GDP per capita growth (annual %)': 3.7510544526,
#   'Livestock production index (2004-2006 = 100)': 38.68,
#   'Ores and metals exports (% of merchandise exports)': 2.7669993926,
#   'Urban population': 14324149.0,
#   'Year': 1991},
#  {'Agricultural land (sq. km)': 960050.0,
#   'Country Code': 'ZAF',
#   'Country Name': 'South Africa',
#   'Crop production index (2004-2006 = 100)': 84.81,
#   'Electric power consumption (kWh per capita)': 4128.2697423974,
#   'Food production index (2004-2006 = 100)': 81.71,
#   'Forest area (% of land area)': 7.6177365241,
#   'GDP per capita growth (annual %)': -3.4283857215,
#   'Livestock production index (2004-2006 = 100)': 82.61,
#   'Ores and metals exports (% of merchandise exports)': 2.7669993926,
#   'Urban population': 19822817.0,
#   'Year': 1991},
#  {'Agricultural land (sq. km)': 1277550.0,
#   'Country Code': 'ARG',
#   'Country Name': 'Argentina',
#   'Crop production index (2004-2006 = 100)': 58.01,
#   'Electric power consumption (kWh per capita)': 1410.3772918072,
#   'Food production index (2004-2006 = 100)': 65.31,
#   'Forest area (% of land area)': 12.4991864031,
#   'GDP per capita growth (annual %)': 6.4876063239,
#   'Livestock production index (2004-2006 = 100)': 81.87,
#   'Ores and metals exports (% of merchandise exports)': 1.1682502821,
#   'Urban population': 29352243.0,
#   'Year': 1992},
#  {'Agricultural land (sq. km)': 4661780.0,
#   'Country Code': 'AUS',
#   'Country Name': 'Australia',
#   'Crop production index (2004-2006 = 100)': 67.34,
#   'Electric power consumption (kWh per capita)': 8550.328665333,
#   'Food production index (2004-2006 = 100)': 74.63,
#   'Forest area (% of land area)': 16.7399086211,
#   'GDP per capita growth (annual %)': -0.7985051087,
#   'Livestock production index (2004-2006 = 100)': 87.79,
#   'Ores and metals exports (% of merchandise exports)': 18.7803860499,
#   'Urban population': 14920611.0,
#   'Year': 1992},
#  {'Agricultural land (sq. km)': 61450.0,
#   'Country Code': 'BEL',
#   'Country Name': 'Belgium',
#   'Crop production index (2004-2006 = 100)': 75.2766344116,
#   'Electric power consumption (kWh per capita)': 6850.663772536,
#   'Food production index (2004-2006 = 100)': 74.55,
#   'Forest area (% of land area)': 31.6496987293,
#   'GDP per capita growth (annual %)': 1.1195657528,
#   'Livestock production index (2004-2006 = 100)': 76.74,
#   'Ores and metals exports (% of merchandise exports)': 3.523208789,
#   'Urban population': 9697796.0,
#   'Year': 1992},
#  {'Agricultural land (sq. km)': 2467090.0,
#   'Country Code': 'BRA',
#   'Country Name': 'Brazil',
#   'Crop production index (2004-2006 = 100)': 64.06,
#   'Electric power consumption (kWh per capita)': 1494.0614956445,
#   'Food production index (2004-2006 = 100)': 56.89,
#   'Forest area (% of land area)': 64.801356821,
#   'GDP per capita growth (annual %)': -2.1518520292,
#   'Livestock production index (2004-2006 = 100)': 51.65,
#   'Ores and metals exports (% of merchandise exports)': 11.8909928373,
#   'Urban population': 116379447.0,
#   'Year': 1992},
#  {'Agricultural land (sq. km)': 678140.0,
#   'Country Code': 'CAN',
#   'Country Name': 'Canada',
#   'Crop production index (2004-2006 = 100)': 76.46,
#   'Electric power consumption (kWh per capita)': 16164.419040336,
#   'Food production index (2004-2006 = 100)': 73.29,
#   'Forest area (% of land area)': 38.2887149736,
#   'GDP per capita growth (annual %)': -0.2870314254,
#   'Livestock production index (2004-2006 = 100)': 70.68,
#   'Ores and metals exports (% of merchandise exports)': 7.3014154267,
#   'Urban population': 21813814.0,
#   'Year': 1992},
#  {'Agricultural land (sq. km)': 155560.0,
#   'Country Code': 'CHL',
#   'Country Name': 'Chile',
#   'Crop production index (2004-2006 = 100)': 66.82,
#   'Electric power consumption (kWh per capita)': 1457.0891933778,
#   'Food production index (2004-2006 = 100)': 62.52,
#   'Forest area (% of land area)': 20.6812881611,
#   'GDP per capita growth (annual %)': 9.3471715538,
#   'Livestock production index (2004-2006 = 100)': 57.34,
#   'Ores and metals exports (% of merchandise exports)': 46.7871576034,
#   'Urban population': 11464830.0,
#   'Year': 1992},
#  {'Agricultural land (sq. km)': 169510.0,
#   'Country Code': 'DEU',
#   'Country Name': 'Germany',
#   'Crop production index (2004-2006 = 100)': 84.97,
#   'Electric power consumption (kWh per capita)': 6445.8739998927,
#   'Food production index (2004-2006 = 100)': 95.7,
#   'Forest area (% of land area)': 32.3971008068,
#   'GDP per capita growth (annual %)': 1.1560053538,
#   'Livestock production index (2004-2006 = 100)': 97.32,
#   'Ores and metals exports (% of merchandise exports)': 2.3574670004,
#   'Urban population': 59146205.0,
#   'Year': 1992},
#  {'Agricultural land (sq. km)': 180700.0,
#   'Country Code': 'GBR',
#   'Country Name': 'United Kingdom',
#   'Crop production index (2004-2006 = 100)': 110.42,
#   'Electric power consumption (kWh per capita)': 5452.3933334123,
#   'Food production index (2004-2006 = 100)': 110.59,
#   'Forest area (% of land area)': 11.6281567031,
#   'GDP per capita growth (annual %)': 0.0999580468,
#   'Livestock production index (2004-2006 = 100)': 108.11,
#   'Ores and metals exports (% of merchandise exports)': 2.4105756597,
#   'Urban population': 45011752.0,
#   'Year': 1992},
#  {'Agricultural land (sq. km)': 13262501.0073406,
#   'Country Code': 'HIC',
#   'Country Name': 'High Income Countries',
#   'Crop production index (2004-2006 = 100)': 89.886609823,
#   'Electric power consumption (kWh per capita)': 7480.5789491048,
#   'Food production index (2004-2006 = 100)': 89.7118660707,
#   'Forest area (% of land area)': 28.5050686755,
#   'GDP per capita growth (annual %)': 1.4435097833,
#   'Livestock production index (2004-2006 = 100)': 89.552111603,
#   'Ores and metals exports (% of merchandise exports)': 4.5076587871,
#   'Urban population': 761461407.0,
#   'Year': 1992},
#  {'Agricultural land (sq. km)': 1813050.0,
#   'Country Code': 'IND',
#   'Country Name': 'India',
#   'Crop production index (2004-2006 = 100)': 77.07,
#   'Electric power consumption (kWh per capita)': 304.4318311957,
#   'Food production index (2004-2006 = 100)': 74.12,
#   'Forest area (% of land area)': 21.6027900063,
#   'GDP per capita growth (annual %)': 3.3904192324,
#   'Livestock production index (2004-2006 = 100)': 63.8,
#   'Ores and metals exports (% of merchandise exports)': 4.2666857721,
#   'Urban population': 236274335.0,
#   'Year': 1992},
#  {'Agricultural land (sq. km)': 45150.0,
#   'Country Code': 'KHM',
#   'Country Name': 'Cambodia',
#   'Crop production index (2004-2006 = 100)': 44.56,
#   'Electric power consumption (kWh per capita)': 1310.4574570279,
#   'Food production index (2004-2006 = 100)': 48.01,
#   'Forest area (% of land area)': 71.7448469897,
#   'GDP per capita growth (annual %)': 0.5980377415,
#   'Livestock production index (2004-2006 = 100)': 67.29,
#   'Ores and metals exports (% of merchandise exports)': 2.5861706076,
#   'Urban population': 1562342.0,
#   'Year': 1992},
#  {'Agricultural land (sq. km)': 4517382.00195313,
#   'Country Code': 'LIC',
#   'Country Name': 'Low Income Countries',
#   'Crop production index (2004-2006 = 100)': 72.8851153803,
#   'Electric power consumption (kWh per capita)': 1310.4574570279,
#   'Food production index (2004-2006 = 100)': 71.5643994269,
#   'Forest area (% of land area)': 29.5447216155,
#   'GDP per capita growth (annual %)': -6.1378255315,
#   'Livestock production index (2004-2006 = 100)': 70.0263443053,
#   'Ores and metals exports (% of merchandise exports)': 2.5861706076,
#   'Urban population': 84183799.0,
#   'Year': 1992},
#  {'Agricultural land (sq. km)': 29032264.801766,
#   'Country Code': 'MIC',
#   'Country Name': 'Middle Income Countries',
#   'Crop production index (2004-2006 = 100)': 67.1157234085,
#   'Electric power consumption (kWh per capita)': 897.8792714775,
#   'Food production index (2004-2006 = 100)': 65.3940912078,
#   'Forest area (% of land area)': 34.1760546265,
#   'GDP per capita growth (annual %)': -0.8953221938,
#   'Livestock production index (2004-2006 = 100)': 66.352318449,
#   'Ores and metals exports (% of merchandise exports)': 3.7506448105,
#   'Urban population': 1538879791.0,
#   'Year': 1992},
#  {'Agricultural land (sq. km)': 159600.0,
#   'Country Code': 'NZL',
#   'Country Name': 'New Zealnd',
#   'Crop production index (2004-2006 = 100)': 78.13,
#   'Electric power consumption (kWh per capita)': 8636.633915678,
#   'Food production index (2004-2006 = 100)': 70.95,
#   'Forest area (% of land area)': 37.0445489929,
#   'GDP per capita growth (annual %)': 0.0470730533,
#   'Livestock production index (2004-2006 = 100)': 72.94,
#   'Ores and metals exports (% of merchandise exports)': 4.6075103714,
#   'Urban population': 3005583.0,
#   'Year': 1992},
#  {'Agricultural land (sq. km)': 213740.0,
#   'Country Code': 'THA',
#   'Country Name': 'Thailand',
#   'Crop production index (2004-2006 = 100)': 68.56,
#   'Electric power consumption (kWh per capita)': 893.3763684955,
#   'Food production index (2004-2006 = 100)': 77.92,
#   'Forest area (% of land area)': 28.5897163681,
#   'GDP per capita growth (annual %)': 7.001720695,
#   'Livestock production index (2004-2006 = 100)': 99.14,
#   'Ores and metals exports (% of merchandise exports)': 0.5952589826,
#   'Urban population': 17206294.0,
#   'Year': 1992},
#  {'Agricultural land (sq. km)': 4254290.0,
#   'Country Code': 'USA',
#   'Country Name': 'United States of America',
#   'Crop production index (2004-2006 = 100)': 87.07,
#   'Electric power consumption (kWh per capita)': 12014.9582478929,
#   'Food production index (2004-2006 = 100)': 84.23,
#   'Forest area (% of land area)': 33.0460213277,
#   'GDP per capita growth (annual %)': 2.0966147054,
#   'Livestock production index (2004-2006 = 100)': 82.92,
#   'Ores and metals exports (% of merchandise exports)': 2.3262720271,
#   'Urban population': 195199459.0,
#   'Year': 1992},
#  {'Agricultural land (sq. km)': 70250.0,
#   'Country Code': 'VNM',
#   'Country Name': 'Vietnam',
#   'Crop production index (2004-2006 = 100)': 51.1,
#   'Electric power consumption (kWh per capita)': 101.8431924922,
#   'Food production index (2004-2006 = 100)': 53.8,
#   'Forest area (% of land area)': 30.2184392906,
#   'GDP per capita growth (annual %)': 6.4288956087,
#   'Livestock production index (2004-2006 = 100)': 42.72,
#   'Ores and metals exports (% of merchandise exports)': 2.5861706076,
#   'Urban population': 14889784.0,
#   'Year': 1992},
#  {'Agricultural land (sq. km)': 964730.0,
#   'Country Code': 'ZAF',
#   'Country Name': 'South Africa',
#   'Crop production index (2004-2006 = 100)': 62.13,
#   'Electric power consumption (kWh per capita)': 3997.0411097447,
#   'Food production index (2004-2006 = 100)': 69.38,
#   'Forest area (% of land area)': 7.6177365241,
#   'GDP per capita growth (annual %)': -4.5503330545,
#   'Livestock production index (2004-2006 = 100)': 82.87,
#   'Ores and metals exports (% of merchandise exports)': 10.152943888,
#   'Urban population': 20511177.0,
#   'Year': 1992},
#  {'Agricultural land (sq. km)': 1278500.0,
#   'Country Code': 'ARG',
#   'Country Name': 'Argentina',
#   'Crop production index (2004-2006 = 100)': 54.57,
#   'Electric power consumption (kWh per capita)': 1496.9041461183,
#   'Food production index (2004-2006 = 100)': 64.75,
#   'Forest area (% of land area)': 12.3920142809,
#   'GDP per capita growth (annual %)': 6.8029208614,
#   'Livestock production index (2004-2006 = 100)': 86.41,
#   'Ores and metals exports (% of merchandise exports)': 1.1605816892,
#   'Urban population': 29809452.0,
#   'Year': 1993},
#  {'Agricultural land (sq. km)': 4602860.0,
#   'Country Code': 'AUS',
#   'Country Name': 'Australia',
#   'Crop production index (2004-2006 = 100)': 69.05,
#   'Electric power consumption (kWh per capita)': 8701.7603441444,
#   'Food production index (2004-2006 = 100)': 78.22,
#   'Forest area (% of land area)': 16.7438137016,
#   'GDP per capita growth (annual %)': 3.0166131583,
#   'Livestock production index (2004-2006 = 100)': 89.94,
#   'Ores and metals exports (% of merchandise exports)': 17.4591603228,
#   'Urban population': 15044687.0,
#   'Year': 1993},
#  {'Agricultural land (sq. km)': 61255.0,
#   'Country Code': 'BEL',
#   'Country Name': 'Belgium',
#   'Crop production index (2004-2006 = 100)': 77.7579397725,
#   'Electric power consumption (kWh per capita)': 6881.0721430714,
#   'Food production index (2004-2006 = 100)': 76.4812813868,
#   'Forest area (% of land area)': 30.9447473092,
#   'GDP per capita growth (annual %)': -1.3479994912,
#   'Livestock production index (2004-2006 = 100)': 78.2,
#   'Ores and metals exports (% of merchandise exports)': 3.298697966,
#   'Urban population': 9743821.0,
#   'Year': 1993},
#  {'Agricultural land (sq. km)': 2494630.0,
#   'Country Code': 'BRA',
#   'Country Name': 'Brazil',
#   'Crop production index (2004-2006 = 100)': 62.89,
#   'Electric power consumption (kWh per capita)': 1537.5927169938,
#   'Food production index (2004-2006 = 100)': 57.45,
#   'Forest area (% of land area)': 64.4970875697,
#   'GDP per capita growth (annual %)': 2.93706716,
#   'Livestock production index (2004-2006 = 100)': 53.47,
#   'Ores and metals exports (% of merchandise exports)': 10.5855019887,
#   'Urban population': 119489196.0,
#   'Year': 1993},
#  {'Agricultural land (sq. km)': 678740.0,
#   'Country Code': 'CAN',
#   'Country Name': 'Canada',
#   'Crop production index (2004-2006 = 100)': 83.38,
#   'Electric power consumption (kWh per capita)': 16320.127298241,
#   'Food production index (2004-2006 = 100)': 73.04,
#   'Forest area (% of land area)': 38.2835327063,
#   'GDP per capita growth (annual %)': 1.5388609928,
#   'Livestock production index (2004-2006 = 100)': 69.61,
#   'Ores and metals exports (% of merchandise exports)': 6.0955790796,
#   'Urban population': 22130869.0,
#   'Year': 1993},
#  {'Agricultural land (sq. km)': 154770.0,
#   'Country Code': 'CHL',
#   'Country Name': 'Chile',
#   'Crop production index (2004-2006 = 100)': 69.49,
#   'Electric power consumption (kWh per capita)': 1514.7433079117,
#   'Food production index (2004-2006 = 100)': 66.47,
#   'Forest area (% of land area)': 20.7580832513,
#   'GDP per capita growth (annual %)': 4.8680837734,
#   'Livestock production index (2004-2006 = 100)': 63.11,
#   'Ores and metals exports (% of merchandise exports)': 43.1408742888,
#   'Urban population': 11699244.0,
#   'Year': 1993},
#  {'Agricultural land (sq. km)': 171620.0,
#   'Country Code': 'DEU',
#   'Country Name': 'Germany',
#   'Crop production index (2004-2006 = 100)': 85.23,
#   'Electric power consumption (kWh per capita)': 6288.4163500526,
#   'Food production index (2004-2006 = 100)': 93.1,
#   'Forest area (% of land area)': 32.4134973514,
#   'GDP per capita growth (annual %)': -1.6281580567,
#   'Livestock production index (2004-2006 = 100)': 95.92,
#   'Ores and metals exports (% of merchandise exports)': 2.4027835019,
#   'Urban population': 59647492.0,
#   'Year': 1993},
#  {'Agricultural land (sq. km)': 175340.0,
#   'Country Code': 'GBR',
#   'Country Name': 'United Kingdom',
#   'Crop production index (2004-2006 = 100)': 103.8,
#   'Electric power consumption (kWh per capita)': 5491.9891181032,
#   'Food production index (2004-2006 = 100)': 107.3,
#   'Forest area (% of land area)': 11.7009054223,
#   'GDP per capita growth (annual %)': 2.2808391409,
#   'Livestock production index (2004-2006 = 100)': 107.16,
#   'Ores and metals exports (% of merchandise exports)': 2.5676679362,
#   'Urban population': 45154426.0,
#   'Year': 1993},
#  {'Agricultural land (sq. km)': 13304383.0072528,
#   'Country Code': 'HIC',
#   'Country Name': 'High Income Countries',
#   'Crop production index (2004-2006 = 100)': 84.3584895687,
#   'Electric power consumption (kWh per capita)': 7583.653210233,
#   'Food production index (2004-2006 = 100)': 86.3332374452,
#   'Forest area (% of land area)': 28.5316608343,
#   'GDP per capita growth (annual %)': 0.3946947434,
#   'Livestock production index (2004-2006 = 100)': 89.7725197285,
#   'Ores and metals exports (% of merchandise exports)': 4.0540075427,
#   'Urban population': 770008802.0,
#   'Year': 1993},
#  {'Agricultural land (sq. km)': 1813820.0,
#   'Country Code': 'IND',
#   'Country Name': 'India',
#   'Crop production index (2004-2006 = 100)': 79.74,
#   'Electric power consumption (kWh per capita)': 320.550746899,
#   'Food production index (2004-2006 = 100)': 76.9,
#   'Forest area (% of land area)': 21.6515933328,
#   'GDP per capita growth (annual %)': 2.7067277335,
#   'Livestock production index (2004-2006 = 100)': 66.06,
#   'Ores and metals exports (% of merchandise exports)': 3.7013931178,
#   'Urban population': 242896345.0,
#   'Year': 1993},
#  {'Agricultural land (sq. km)': 45310.0,
#   'Country Code': 'KHM',
#   'Country Name': 'Cambodia',
#   'Crop production index (2004-2006 = 100)': 45.85,
#   'Electric power consumption (kWh per capita)': 1284.7056225937,
#   'Food production index (2004-2006 = 100)': 49.93,
#   'Forest area (% of land area)': 70.9528643178,
#   'GDP per capita growth (annual %)': 0.6955879165,
#   'Livestock production index (2004-2006 = 100)': 70.33,
#   'Ores and metals exports (% of merchandise exports)': 2.4274472247,
#   'Urban population': 1653845.0,
#   'Year': 1993},
#  {'Agricultural land (sq. km)': 4912343.99902344,
#   'Country Code': 'LIC',
#   'Country Name': 'Low Income Countries',
#   'Crop production index (2004-2006 = 100)': 73.4530264899,
#   'Electric power consumption (kWh per capita)': 1284.7056225937,
#   'Food production index (2004-2006 = 100)': 71.9029554791,
#   'Forest area (% of land area)': 28.3200217341,
#   'GDP per capita growth (annual %)': -3.485824695,
#   'Livestock production index (2004-2006 = 100)': 68.7369682306,
#   'Ores and metals exports (% of merchandise exports)': 2.4274472247,
#   'Urban population': 87806026.0,
#   'Year': 1993},
#  {'Agricultural land (sq. km)': 29074058.0000082,
#   'Country Code': 'MIC',
#   'Country Name': 'Middle Income Countries',
#   'Crop production index (2004-2006 = 100)': 69.0988202866,
#   'Electric power consumption (kWh per capita)': 894.4131632436,
#   'Food production index (2004-2006 = 100)': 67.8514501502,
#   'Forest area (% of land area)': 34.1009091448,
#   'GDP per capita growth (annual %)': 1.0785539419,
#   'Livestock production index (2004-2006 = 100)': 68.7233728853,
#   'Ores and metals exports (% of merchandise exports)': 3.3986087556,
#   'Urban population': 1584014612.0,
#   'Year': 1993},
#  {'Agricultural land (sq. km)': 159190.0,
#   'Country Code': 'NZL',
#   'Country Name': 'New Zealnd',
#   'Crop production index (2004-2006 = 100)': 77.59,
#   'Electric power consumption (kWh per capita)': 8909.3555791949,
#   'Food production index (2004-2006 = 100)': 72.74,
#   'Forest area (% of land area)': 37.2272219235,
#   'GDP per capita growth (annual %)': 5.1854147604,
#   'Livestock production index (2004-2006 = 100)': 74.24,
#   'Ores and metals exports (% of merchandise exports)': 4.2994446631,
#   'Urban population': 3045443.0,
#   'Year': 1993},
#  {'Agricultural land (sq. km)': 212450.0,
#   'Country Code': 'THA',
#   'Country Name': 'Thailand',
#   'Crop production index (2004-2006 = 100)': 66.79,
#   'Electric power consumption (kWh per capita)': 1008.5232427367,
#   'Food production index (2004-2006 = 100)': 76.35,
#   'Forest area (% of land area)': 29.1781005788,
#   'GDP per capita growth (annual %)': 7.2736068829,
#   'Livestock production index (2004-2006 = 100)': 100.81,
#   'Ores and metals exports (% of merchandise exports)': 0.5279760902,
#   'Urban population': 17462829.0,
#   'Year': 1993},
#  {'Agricultural land (sq. km)': 4229480.0,
#   'Country Code': 'USA',
#   'Country Name': 'United States of America',
#   'Crop production index (2004-2006 = 100)': 74.25,
#   'Electric power consumption (kWh per capita)': 12261.5237824091,
#   'Food production index (2004-2006 = 100)': 76.98,
#   'Forest area (% of land area)': 33.0578812988,
#   'GDP per capita growth (annual %)': 1.4067579118,
#   'Livestock production index (2004-2006 = 100)': 83.13,
#   'Ores and metals exports (% of merchandise exports)': 2.1340280064,
#   'Urban population': 198806845.0,
#   'Year': 1993},
#  {'Agricultural land (sq. km)': 70870.0,
#   'Country Code': 'VNM',
#   'Country Name': 'Vietnam',
#   'Crop production index (2004-2006 = 100)': 54.08,
#   'Electric power consumption (kWh per capita)': 112.0603801577,
#   'Food production index (2004-2006 = 100)': 56.28,
#   'Forest area (% of land area)': 30.9447300848,
#   'GDP per capita growth (annual %)': 5.9548923381,
#   'Livestock production index (2004-2006 = 100)': 44.12,
#   'Ores and metals exports (% of merchandise exports)': 2.4274472247,
#   'Urban population': 15462867.0,
#   'Year': 1993},
#  {'Agricultural land (sq. km)': 969360.0,
#   'Country Code': 'ZAF',
#   'Country Name': 'South Africa',
#   'Crop production index (2004-2006 = 100)': 80.26,
#   'Electric power consumption (kWh per capita)': 4023.2882328823,
#   'Food production index (2004-2006 = 100)': 78.57,
#   'Forest area (% of land area)': 7.6177365241,
#   'GDP per capita growth (annual %)': -1.2214556827,
#   'Livestock production index (2004-2006 = 100)': 80.85,
#   'Ores and metals exports (% of merchandise exports)': 7.7014153643,
#   'Urban population': 21212379.0,
#   'Year': 1993},
#  {'Agricultural land (sq. km)': 1279480.0,
#   'Country Code': 'ARG',
#   'Country Name': 'Argentina',
#   'Crop production index (2004-2006 = 100)': 58.54,
#   'Electric power consumption (kWh per capita)': 1576.767060419,
#   'Food production index (2004-2006 = 100)': 68.92,
#   'Forest area (% of land area)': 12.2848407314,
#   'GDP per capita growth (annual %)': 4.5054722994,
#   'Livestock production index (2004-2006 = 100)': 90.28,
#   'Ores and metals exports (% of merchandise exports)': 1.315317541,
#   'Urban population': 30260590.0,
#   'Year': 1994},
#  {'Agricultural land (sq. km)': 4691000.0,
#   'Country Code': 'AUS',
#   'Country Name': 'Australia',
#   'Crop production index (2004-2006 = 100)': 54.3,
#   'Electric power consumption (kWh per capita)': 8812.4894987398,
#   'Food production index (2004-2006 = 100)': 73.42,
#   'Forest area (% of land area)': 16.7477187821,
#   'GDP per capita growth (annual %)': 2.8878340457,
#   'Livestock production index (2004-2006 = 100)': 92.22,
#   'Ores and metals exports (% of merchandise exports)': 15.4695810051,
#   'Urban population': 15181749.0,
#   'Year': 1994},
#  {'Agricultural land (sq. km)': 61405.0,
#   'Country Code': 'BEL',
#   'Country Name': 'Belgium',
#   'Crop production index (2004-2006 = 100)': 78.73,
#   'Electric power consumption (kWh per capita)': 7176.2405068684,
#   'Food production index (2004-2006 = 100)': 77.0690501384,
#   'Forest area (% of land area)': 31.1202810861,
#   'GDP per capita growth (annual %)': 2.9093187109,
#   'Livestock production index (2004-2006 = 100)': 79.0101348621,
#   'Ores and metals exports (% of merchandise exports)': 3.3562712414,
#   'Urban population': 9781788.0,
#   'Year': 1994},
#  {'Agricultural land (sq. km)': 2514180.0,
#   'Country Code': 'BRA',
#   'Country Name': 'Brazil',
#   'Crop production index (2004-2006 = 100)': 68.28,
#   'Electric power consumption (kWh per capita)': 1566.7612411495,
#   'Food production index (2004-2006 = 100)': 62.05,
#   'Forest area (% of land area)': 64.1928257962,
#   'GDP per capita growth (annual %)': 3.6275849177,
#   'Livestock production index (2004-2006 = 100)': 56.53,
#   'Ores and metals exports (% of merchandise exports)': 9.6098094633,
#   'Urban population': 122608542.0,
#   'Year': 1994},
#  {'Agricultural land (sq. km)': 679340.0,
#   'Country Code': 'CAN',
#   'Country Name': 'Canada',
#   'Crop production index (2004-2006 = 100)': 85.8,
#   'Electric power consumption (kWh per capita)': 16388.2805024147,
#   'Food production index (2004-2006 = 100)': 76.13,
#   'Forest area (% of land area)': 38.2783538755,
#   'GDP per capita growth (annual %)': 3.3562268127,
#   'Livestock production index (2004-2006 = 100)': 71.33,
#   'Ores and metals exports (% of merchandise exports)': 5.9698783839,
#   'Urban population': 22450573.0,
#   'Year': 1994},
#  {'Agricultural land (sq. km)': 154500.0,
#   'Country Code': 'CHL',
#   'Country Name': 'Chile',
#   'Crop production index (2004-2006 = 100)': 74.44,
#   'Electric power consumption (kWh per capita)': 1588.6954569776,
#   'Food production index (2004-2006 = 100)': 71.84,
#   'Forest area (% of land area)': 20.8348796549,
#   'GDP per capita growth (annual %)': 3.3887012378,
#   'Livestock production index (2004-2006 = 100)': 68.56,
#   'Ores and metals exports (% of merchandise exports)': 43.4033427936,
#   'Urban population': 11931317.0,
#   'Year': 1994},
#  {'Agricultural land (sq. km)': 173080.0,
#   'Country Code': 'DEU',
#   'Country Name': 'Germany',
#   'Crop production index (2004-2006 = 100)': 81.26,
#   'Electric power consumption (kWh per capita)': 6244.9572282581,
#   'Food production index (2004-2006 = 100)': 89.86,
#   'Forest area (% of land area)': 32.429892038,
#   'GDP per capita growth (annual %)': 2.0434899065,
#   'Livestock production index (2004-2006 = 100)': 93.36,
#   'Ores and metals exports (% of merchandise exports)': 2.4163659975,
#   'Urban population': 60028206.0,
#   'Year': 1994},
#  {'Agricultural land (sq. km)': 174090.0,
#   'Country Code': 'GBR',
#   'Country Name': 'United Kingdom',
#   'Crop production index (2004-2006 = 100)': 98.86,
#   'Electric power consumption (kWh per capita)': 5380.2642651538,
#   'Food production index (2004-2006 = 100)': 107.24,
#   'Forest area (% of land area)': 11.7736531325,
#   'GDP per capita growth (annual %)': 3.6307924118,
#   'Livestock production index (2004-2006 = 100)': 110.49,
#   'Ores and metals exports (% of merchandise exports)': 2.5481275039,
#   'Urban population': 45304828.0,
#   'Year': 1994},
#  {'Agricultural land (sq. km)': 13430480.0043231,
#   'Country Code': 'HIC',
#   'Country Name': 'High Income Countries',
#   'Crop production index (2004-2006 = 100)': 90.479410017,
#   'Electric power consumption (kWh per capita)': 7752.2434257375,
#   'Food production index (2004-2006 = 100)': 89.8858555726,
#   'Forest area (% of land area)': 28.5582041853,
#   'GDP per capita growth (annual %)': 2.410172277,
#   'Livestock production index (2004-2006 = 100)': 90.9442512829,
#   'Ores and metals exports (% of merchandise exports)': 2.9126540705,
#   'Urban population': 778343596.0,
#   'Year': 1994},
#  {'Agricultural land (sq. km)': 1812910.0,
#   'Country Code': 'IND',
#   'Country Name': 'India',
#   'Crop production index (2004-2006 = 100)': 82.07,
#   'Electric power consumption (kWh per capita)': 341.2313612578,
#   'Food production index (2004-2006 = 100)': 79.03,
#   'Forest area (% of land area)': 21.7003953456,
#   'GDP per capita growth (annual %)': 4.6062884406,
#   'Livestock production index (2004-2006 = 100)': 68.33,
#   'Ores and metals exports (% of merchandise exports)': 3.4798347775,
#   'Urban population': 249629427.0,
#   'Year': 1994},
#  {'Agricultural land (sq. km)': 45700.0,
#   'Country Code': 'KHM',
#   'Country Name': 'Cambodia',
#   'Crop production index (2004-2006 = 100)': 44.41,
#   'Electric power consumption (kWh per capita)': 1312.2056623272,
#   'Food production index (2004-2006 = 100)': 48.08,
#   'Forest area (% of land area)': 70.1608871782,
#   'GDP per capita growth (annual %)': -37.0021303071,
#   'Livestock production index (2004-2006 = 100)': 69.48,
#   'Ores and metals exports (% of merchandise exports)': 2.410741456,
#   'Urban population': 1748471.0,
#   'Year': 1994},
#  {'Agricultural land (sq. km)': 4932756.00097656,
#   'Country Code': 'LIC',
#   'Country Name': 'Low Income Countries',
#   'Crop production index (2004-2006 = 100)': 72.2139636659,
#   'Electric power consumption (kWh per capita)': 1312.2056623272,
#   'Food production index (2004-2006 = 100)': 71.8314475434,
#   'Forest area (% of land area)': 28.1737149385,
#   'GDP per capita growth (annual %)': -2.5993153045,
#   'Livestock production index (2004-2006 = 100)': 70.6964380081,
#   'Ores and metals exports (% of merchandise exports)': 2.410741456,
#   'Urban population': 91451765.0,
#   'Year': 1994},
#  {'Agricultural land (sq. km)': 29144094.0029302,
#   'Country Code': 'MIC',
#   'Country Name': 'Middle Income Countries',
#   'Crop production index (2004-2006 = 100)': 69.8359013601,
#   'Electric power consumption (kWh per capita)': 895.6561690732,
#   'Food production index (2004-2006 = 100)': 69.4725262749,
#   'Forest area (% of land area)': 34.0292384091,
#   'GDP per capita growth (annual %)': 0.797277174,
#   'Livestock production index (2004-2006 = 100)': 71.2352714786,
#   'Ores and metals exports (% of merchandise exports)': 3.2281282885,
#   'Urban population': 1629416844.0,
#   'Year': 1994},
#  {'Agricultural land (sq. km)': 151160.0,
#   'Country Code': 'NZL',
#   'Country Name': 'New Zealnd',
#   'Crop production index (2004-2006 = 100)': 88.92,
#   'Electric power consumption (kWh per capita)': 8927.9005524862,
#   'Food production index (2004-2006 = 100)': 76.18,
#   'Forest area (% of land area)': 37.409898563,
#   'GDP per capita growth (annual %)': 3.7303720291,
#   'Livestock production index (2004-2006 = 100)': 77.21,
#   'Ores and metals exports (% of merchandise exports)': 4.3628934076,
#   'Urban population': 3091625.0,
#   'Year': 1994},
#  {'Agricultural land (sq. km)': 211200.0,
#   'Country Code': 'THA',
#   'Country Name': 'Thailand',
#   'Crop production index (2004-2006 = 100)': 70.83,
#   'Electric power consumption (kWh per capita)': 1106.3388941798,
# ...
#   'Year': 2044},
#  {'Agricultural land (sq. km)': 2805170.6511699557,
#   'Country Code': 'AUS',
#   'Country Name': 'Australia',
#   'Crop production index (2004-2006 = 100)': 155.7420689655,
#   'Electric power consumption (kWh per capita)': 12528.7664146287,
#   'Food production index (2004-2006 = 100)': 142.8071921182,
#   'Forest area (% of land area)': 15.2585543269,
#   'GDP per capita growth (annual %)': 0.3195676665,
#   'Livestock production index (2004-2006 = 100)': 119.2948275862,
#   'Ores and metals exports (% of merchandise exports)': 52.7631025525,
#   'Urban population': 27217162.793103456,
#   'Year': 2044},
#  {'Agricultural land (sq. km)': -65030.9453774439,
#   'Country Code': 'BEL',
#   'Country Name': 'Belgium',
#   'Crop production index (2004-2006 = 100)': 120.157300761,
#   'Electric power consumption (kWh per capita)': 9303.0500627207,
#   'Food production index (2004-2006 = 100)': 116.5483914101,
#   'Forest area (% of land area)': 9.3063294282,
#   'GDP per capita growth (annual %)': -0.5439252869,
#   'Livestock production index (2004-2006 = 100)': 109.8562659681,
#   'Ores and metals exports (% of merchandise exports)': 2.3672571719,
#   'Urban population': 12663383.891625628,
#   'Year': 2044},
#  {'Agricultural land (sq. km)': 3243969.8783866987,
#   'Country Code': 'BRA',
#   'Country Name': 'Brazil',
#   'Crop production index (2004-2006 = 100)': 245.1039901478,
#   'Electric power consumption (kWh per capita)': 3913.7736083512,
#   'Food production index (2004-2006 = 100)': 240.0030541872,
#   'Forest area (% of land area)': 51.54819305,
#   'GDP per capita growth (annual %)': 1.2130044534,
#   'Livestock production index (2004-2006 = 100)': 224.9790640394,
#   'Ores and metals exports (% of merchandise exports)': 15.8173416854,
#   'Urban population': 250372238.58128068,
#   'Year': 2044},
#  {'Agricultural land (sq. km)': 558129.9507389162,
#   'Country Code': 'CAN',
#   'Country Name': 'Canada',
#   'Crop production index (2004-2006 = 100)': 194.6697536946,
#   'Electric power consumption (kWh per capita)': 14668.404889692,
#   'Food production index (2004-2006 = 100)': 168.1944334975,
#   'Forest area (% of land area)': 38.0183222098,
#   'GDP per capita growth (annual %)': 1.8028628707,
#   'Livestock production index (2004-2006 = 100)': 113.0346305419,
#   'Ores and metals exports (% of merchandise exports)': 8.9880367234,
#   'Urban population': 38235520.42364526,
#   'Year': 2044},
#  {'Agricultural land (sq. km)': 161906.5997344519,
#   'Country Code': 'CHL',
#   'Country Name': 'Chile',
#   'Crop production index (2004-2006 = 100)': 171.8046305419,
#   'Electric power consumption (kWh per capita)': 6971.6603100506,
#   'Food production index (2004-2006 = 100)': 177.2806403941,
#   'Forest area (% of land area)': 26.8514493082,
#   'GDP per capita growth (annual %)': -2.2409231502,
#   'Livestock production index (2004-2006 = 100)': 181.4938916256,
#   'Ores and metals exports (% of merchandise exports)': 72.0856938203,
#   'Urban population': 21087628.857142866,
#   'Year': 2044},
#  {'Agricultural land (sq. km)': 157981.0344827586,
#   'Country Code': 'DEU',
#   'Country Name': 'Germany',
#   'Crop production index (2004-2006 = 100)': 118.3663054187,
#   'Electric power consumption (kWh per capita)': 8154.6766429711,
#   'Food production index (2004-2006 = 100)': 121.8704433498,
#   'Forest area (% of land area)': 33.1541670112,
#   'GDP per capita growth (annual %)': 0.667053359,
#   'Livestock production index (2004-2006 = 100)': 124.448817734,
#   'Ores and metals exports (% of merchandise exports)': 3.2248671808,
#   'Urban population': 68255537.97536945,
#   'Year': 2044},
#  {'Agricultural land (sq. km)': 166322.0250923645,
#   'Country Code': 'GBR',
#   'Country Name': 'United Kingdom',
#   'Crop production index (2004-2006 = 100)': 95.5389655172,
#   'Electric power consumption (kWh per capita)': 5133.2997642886,
#   'Food production index (2004-2006 = 100)': 97.4445812808,
#   'Forest area (% of land area)': 14.6201930341,
#   'GDP per capita growth (annual %)': -0.3982602202,
#   'Livestock production index (2004-2006 = 100)': 99.4057142857,
#   'Ores and metals exports (% of merchandise exports)': 5.7590055352,
#   'Urban population': 64642537.99507392,
#   'Year': 2044},
#  {'Agricultural land (sq. km)': 11456671.990282908,
#   'Country Code': 'HIC',
#   'Country Name': 'High Income Countries',
#   'Crop production index (2004-2006 = 100)': 138.7400931016,
#   'Electric power consumption (kWh per capita)': 11222.4871639822,
#   'Food production index (2004-2006 = 100)': 143.5329177446,
#   'Forest area (% of land area)': 29.4023222344,
#   'GDP per capita growth (annual %)': 0.1751416475,
#   'Livestock production index (2004-2006 = 100)': 134.9059023737,
#   'Ores and metals exports (% of merchandise exports)': 4.9641677398,
#   'Urban population': 1218564973.5320187,
#   'Year': 2044},
#  {'Agricultural land (sq. km)': 1774060.7881773396,
#   'Country Code': 'IND',
#   'Country Name': 'India',
#   'Crop production index (2004-2006 = 100)': 218.919408867,
#   'Electric power consumption (kWh per capita)': 1360.8991693871,
#   'Food production index (2004-2006 = 100)': 222.49408867,
#   'Forest area (% of land area)': 26.6093823372,
#   'GDP per capita growth (annual %)': 9.7178088309,
#   'Livestock production index (2004-2006 = 100)': 246.0825615764,
#   'Ores and metals exports (% of merchandise exports)': 4.6787423809,
#   'Urban population': 672756668.7241383,
#   'Year': 2044},
#  {'Agricultural land (sq. km)': 68407.5862068966,
#   'Country Code': 'KHM',
#   'Country Name': 'Cambodia',
#   'Crop production index (2004-2006 = 100)': 396.4214778325,
#   'Electric power consumption (kWh per capita)': -748.6895382266,
#   'Food production index (2004-2006 = 100)': 345.6936453202,
#   'Forest area (% of land area)': 30.8629510996,
#   'GDP per capita growth (annual %)': 16.9203778897,
#   'Livestock production index (2004-2006 = 100)': 131.4703448276,
#   'Ores and metals exports (% of merchandise exports)': -1.2779326983,
#   'Urban population': 5705057.8866995275,
#   'Year': 2044},
#  {'Agricultural land (sq. km)': 6954636.814746574,
#   'Country Code': 'LIC',
#   'Country Name': 'Low Income Countries',
#   'Crop production index (2004-2006 = 100)': 191.1510086977,
#   'Electric power consumption (kWh per capita)': 4084.8721143223,
#   'Food production index (2004-2006 = 100)': 194.7471913507,
#   'Forest area (% of land area)': 20.7404856603,
#   'GDP per capita growth (annual %)': 8.5240222216,
#   'Livestock production index (2004-2006 = 100)': 185.4415561471,
#   'Ores and metals exports (% of merchandise exports)': 4.7319151233,
#   'Urban population': 355314021.236454,
#   'Year': 2044},
#  {'Agricultural land (sq. km)': 34700563.288295,
#   'Country Code': 'MIC',
#   'Country Name': 'Middle Income Countries',
#   'Crop production index (2004-2006 = 100)': 195.7151031402,
#   'Electric power consumption (kWh per capita)': 3474.0131635897,
#   'Food production index (2004-2006 = 100)': 199.4626534659,
#   'Forest area (% of land area)': 31.8473436229,
#   'GDP per capita growth (annual %)': 8.6659292417,
#   'Livestock production index (2004-2006 = 100)': 193.9938552464,
#   'Ores and metals exports (% of merchandise exports)': 5.3771966406,
#   'Urban population': 4356730274.561584,
#   'Year': 2044},
#  {'Agricultural land (sq. km)': 38419.9317849446,
#   'Country Code': 'NZL',
#   'Country Name': 'New Zealnd',
#   'Crop production index (2004-2006 = 100)': 169.4874384236,
#   'Electric power consumption (kWh per capita)': 9649.2652355495,
#   'Food production index (2004-2006 = 100)': 173.6073891626,
#   'Forest area (% of land area)': 40.490286134,
#   'GDP per capita growth (annual %)': 1.7079217514,
#   'Livestock production index (2004-2006 = 100)': 165.9424137931,
#   'Ores and metals exports (% of merchandise exports)': 1.4709506964,
#   'Urban population': 5236163.197044343,
#   'Year': 2044},
#  {'Agricultural land (sq. km)': 223723.4975369457,
#   'Country Code': 'THA',
#   'Country Name': 'Thailand',
#   'Crop production index (2004-2006 = 100)': 193.0319704434,
#   'Electric power consumption (kWh per capita)': 4545.4801292516,
#   'Food production index (2004-2006 = 100)': 181.1032019704,
#   'Forest area (% of land area)': 35.7637548786,
#   'GDP per capita growth (annual %)': -0.7091208067,
#   'Livestock production index (2004-2006 = 100)': 179.0962068966,
#   'Ores and metals exports (% of merchandise exports)': 2.3353720204,
#   'Urban population': 53015351.37438417,
#   'Year': 2044},
#  {'Agricultural land (sq. km)': 3845264.581280789,
#   'Country Code': 'USA',
#   'Country Name': 'United States of America',
#   'Crop production index (2004-2006 = 100)': 155.771182266,
#   'Electric power consumption (kWh per capita)': 14252.2407178981,
#   'Food production index (2004-2006 = 100)': 163.3340394089,
#   'Forest area (% of land area)': 34.9595502593,
#   'GDP per capita growth (annual %)': 0.6852622021,
#   'Livestock production index (2004-2006 = 100)': 142.5901477833,
#   'Ores and metals exports (% of merchandise exports)': 4.6750193374,
#   'Urban population': 346217503.0640402,
#   'Year': 2044},
#  {'Agricultural land (sq. km)': 179574.9871555571,
#   'Country Code': 'VNM',
#   'Country Name': 'Vietnam',
#   'Crop production index (2004-2006 = 100)': 238.6380788177,
#   'Electric power consumption (kWh per capita)': 2928.1290194616,
#   'Food production index (2004-2006 = 100)': 239.68408867,
#   'Forest area (% of land area)': 70.4274472031,
#   'GDP per capita growth (annual %)': 4.9067972166,
#   'Livestock production index (2004-2006 = 100)': 294.6519704433,
#   'Ores and metals exports (% of merchandise exports)': -0.1164456344,
#   'Urban population': 51741218.00492621,
#   'Year': 2044},
#  {'Agricultural land (sq. km)': 967702.1182266008,
#   'Country Code': 'ZAF',
#   'Country Name': 'South Africa',
#   'Crop production index (2004-2006 = 100)': 149.5741871921,
#   'Electric power consumption (kWh per capita)': 4496.1591126364,
#   'Food production index (2004-2006 = 100)': 176.984729064,
#   'Forest area (% of land area)': 7.6177365241,
#   'GDP per capita growth (annual %)': 2.9817423796,
#   'Livestock production index (2004-2006 = 100)': 201.7860098522,
#   'Ores and metals exports (% of merchandise exports)': 57.4520606699,
#   'Urban population': 54815049.35467959,
#   'Year': 2044},
#  {'Agricultural land (sq. km)': 1794431.6600985192,
#   'Country Code': 'ARG',
#   'Country Name': 'Argentina',
#   'Crop production index (2004-2006 = 100)': 238.8578522167,
#   'Electric power consumption (kWh per capita)': 5192.6305519404,
#   'Food production index (2004-2006 = 100)': 201.1303793103,
#   'Forest area (% of land area)': 6.6038166241,
#   'GDP per capita growth (annual %)': -2.7439813671,
#   'Livestock production index (2004-2006 = 100)': 138.7821724138,
#   'Ores and metals exports (% of merchandise exports)': 5.5267846896,
#   'Urban population': 52568999.02019704,
#   'Year': 2045},
#  {'Agricultural land (sq. km)': 2767569.651016012,
#   'Country Code': 'AUS',
#   'Country Name': 'Australia',
#   'Crop production index (2004-2006 = 100)': 157.3927241379,
#   'Electric power consumption (kWh per capita)': 12593.0518859253,
#   'Food production index (2004-2006 = 100)': 144.0194581281,
#   'Forest area (% of land area)': 15.2458914742,
#   'GDP per capita growth (annual %)': 0.2856750027,
#   'Livestock production index (2004-2006 = 100)': 119.7997241379,
#   'Ores and metals exports (% of merchandise exports)': 53.4855096546,
#   'Urban population': 27461867.275862094,
#   'Year': 2045},
#  {'Agricultural land (sq. km)': -67426.4379786598,
#   'Country Code': 'BEL',
#   'Country Name': 'Belgium',
#   'Crop production index (2004-2006 = 100)': 120.8977083992,
#   'Electric power consumption (kWh per capita)': 9339.5873732128,
#   'Food production index (2004-2006 = 100)': 117.1993567185,
#   'Forest area (% of land area)': 8.9210682492,
#   'GDP per capita growth (annual %)': -0.5920640685,
#   'Livestock production index (2004-2006 = 100)': 110.3448028044,
#   'Ores and metals exports (% of merchandise exports)': 2.3486808536,
#   'Urban population': 12722615.290640416,
#   'Year': 2045},
#  {'Agricultural land (sq. km)': 3258262.171951968,
#   'Country Code': 'BRA',
#   'Country Name': 'Brazil',
#   'Crop production index (2004-2006 = 100)': 248.7175123153,
#   'Electric power consumption (kWh per capita)': 3960.5678033264,
#   'Food production index (2004-2006 = 100)': 243.5761133005,
#   'Forest area (% of land area)': 51.2845410417,
#   'GDP per capita growth (annual %)': 1.2187403798,
#   'Livestock production index (2004-2006 = 100)': 228.2940147783,
#   'Ores and metals exports (% of merchandise exports)': 15.9235437103,
#   'Urban population': 252898583.97684667,
#   'Year': 2045},
#  {'Agricultural land (sq. km)': 555633.3546798035,
#   'Country Code': 'CAN',
#   'Country Name': 'Canada',
#   'Crop production index (2004-2006 = 100)': 196.9431527094,
#   'Electric power consumption (kWh per capita)': 14628.7761689037,
#   'Food production index (2004-2006 = 100)': 169.9956650246,
#   'Forest area (% of land area)': 38.0125324317,
#   'GDP per capita growth (annual %)': 1.8119541707,
#   'Livestock production index (2004-2006 = 100)': 113.690453202,
#   'Ores and metals exports (% of merchandise exports)': 9.0434405409,
#   'Urban population': 38551213.28078818,
#   'Year': 2045},
#  {'Agricultural land (sq. km)': 162055.6302484221,
#   'Country Code': 'CHL',
#   'Country Name': 'Chile',
#   'Crop production index (2004-2006 = 100)': 173.7767635468,
#   'Electric power consumption (kWh per capita)': 7075.6845646508,
#   'Food production index (2004-2006 = 100)': 179.3916650246,
#   'Forest area (% of land area)': 26.9800788499,
#   'GDP per capita growth (annual %)': -2.3812303216,
#   'Livestock production index (2004-2006 = 100)': 183.7291871921,
#   'Ores and metals exports (% of merchandise exports)': 72.591751847,
#   'Urban population': 21269950.52512318,
#   'Year': 2045},
#  {'Agricultural land (sq. km)': 157679.3103448276,
#   'Country Code': 'DEU',
#   'Country Name': 'Germany',
#   'Crop production index (2004-2006 = 100)': 118.9291871921,
#   'Electric power consumption (kWh per capita)': 8187.3882583458,
#   'Food production index (2004-2006 = 100)': 122.3785320197,
#   'Forest area (% of land area)': 33.2510448109,
#   'GDP per capita growth (annual %)': 0.6463752132,
#   'Livestock production index (2004-2006 = 100)': 124.972546798,
#   'Ores and metals exports (% of merchandise exports)': 3.2403095842,
#   'Urban population': 68417886.93596059,
#   'Year': 2045},
#  {'Agricultural land (sq. km)': 166134.0055418719,
#   'Country Code': 'GBR',
#   'Country Name': 'United Kingdom',
#   'Crop production index (2004-2006 = 100)': 95.3685517241,
#   'Electric power consumption (kWh per capita)': 5119.4792342018,
#   'Food production index (2004-2006 = 100)': 97.2787044335,
#   'Forest area (% of land area)': 14.6754988568,
#   'GDP per capita growth (annual %)': -0.4456927779,
#   'Livestock production index (2004-2006 = 100)': 99.2879605911,
#   'Ores and metals exports (% of merchandise exports)': 5.8254981449,
#   'Urban population': 65038950.48374391,
#   'Year': 2045},
#  {'Agricultural land (sq. km)': 11416279.332884908,
#   'Country Code': 'HIC',
#   'Country Name': 'High Income Countries',
#   'Crop production index (2004-2006 = 100)': 139.7338139694,
#   'Electric power consumption (kWh per capita)': 11286.487378941,
#   'Food production index (2004-2006 = 100)': 144.6159485348,
#   'Forest area (% of land area)': 29.4142165429,
#   'GDP per capita growth (annual %)': 0.1423693232,
#   'Livestock production index (2004-2006 = 100)': 135.7778489626,
#   'Ores and metals exports (% of merchandise exports)': 4.9962398732,
#   'Urban population': 1227369267.6211836,
#   'Year': 2045},
#  {'Agricultural land (sq. km)': 1773320.0837438419,
#   'Country Code': 'IND',
#   'Country Name': 'India',
#   'Crop production index (2004-2006 = 100)': 221.7255665025,
#   'Electric power consumption (kWh per capita)': 1381.9843155386,
#   'Food production index (2004-2006 = 100)': 225.4161133005,
#   'Forest area (% of land area)': 26.6881650764,
#   'GDP per capita growth (annual %)': 9.8440300976,
#   'Livestock production index (2004-2006 = 100)': 249.6717635468,
#   'Ores and metals exports (% of merchandise exports)': 4.6892715269,
#   'Urban population': 681272658.424139,
#   'Year': 2045},
#  ...]
